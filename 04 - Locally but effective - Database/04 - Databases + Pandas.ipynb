# %%
# import a bounch of stuff that allow us to play with sqlalchemy as ORM
from sqlalchemy import create_engine
from sqlalchemy import Column, DateTime, String, Text, Integer, ForeignKey, func, Boolean, update, or_, desc # some datatype and filters
from sqlalchemy.orm import relationship, backref, sessionmaker,session # session plus a little more
from sqlalchemy.ext.declarative import declarative_base

# %% [markdown]
# # Create SQLite DB with a Table

# %%
# we inicialize the declarative mode 
Base = declarative_base()

# we create a class that will map the columns in the db
class MyTable(Base):
    # table name
    __tablename__ = 'mytable'
    # all columns 
    id = Column('id',Integer, primary_key=True, autoincrement=True )
    address = Column('address',Text )
    price = Column('price',Text)
    rooms = Column('rooms',Text)
    bathrooms = Column('bathrooms',Text)
    area = Column('area',Text)
    url = Column('url',Text) # Text, can be also Integer, Boolean 

# were we gonna store the SQLite DB
db = create_engine("sqlite:///database.sqlite")
# it will plot the log of the dialog of the db
db.echo = False  # Try changing this to True 

# here we create the table if not present
session = sessionmaker()
session.configure(bind=db)
Base.metadata.create_all(db)

# %% [markdown]
# # we need to populate the table, we will use the data.csv as example

# %%
import csv
# like in the first file, we loop thru rows 
file = open('data.csv','r')
reader = csv.reader(file)
for row in reader:
    # one by one, and we print the results
    print(row)
    
file.close()
# Out:
# ['name', 'price', 'rooms', 'bathrooms', 'area', 'url']
# ['Trilocale via pinerolo, Rivalta di Torino', '€ 78.000', '3', '1', 'None', 'https://www.immobiliare.it/63854720-Vendita-Trilocale-via-pinerolo-Rivalta-di-Torino.html']
# ['Bilocale via Luigi Salvatore Cherubini 20, Torino', '€ 49.000', '2', '1', '55', 'https://www.immobiliare.it/63858966-Vendita-Bilocale-via-Luigi-Salvatore-Torino.html']
# ['Quadrilocale via Luigi Salvatore Cherubini 20, Torino', '€ 79.000', '4', '1', '85', 'https://www.immobiliare.it/63857262-Vendita-Quadrilocale-via-Luigi-Salvatore-Torino.html']
# ['Quadrilocale via Bibiana, Torino', '€ 108.000', '2', '95', 'None', 'https://www.immobiliare.it/63854132-Vendita-Quadrilocale-via-Bibiana-Torino.html']
# ['Quadrilocale corso Monte Cucco, Torino', '€ 218.000', '4', '1', '130', 'https://www.immobiliare.it/63854506-Vendita-Quadrilocale-corso-Monte-Cucco-Torino.html']
# ['Bilocale via Erminio Macario 8, Chieri', '€ 90.000', '2', '2', '60', 'https://www.immobiliare.it/63857368-Vendita-Bilocale-via-Erminio-Macario-8-Chieri.html']
# ['Appartamento via Amendola, Chieri', '€ 260.000', '5', '2', '155', 'https://www.immobiliare.it/63857376-Vendita-Appartamento-via-Amendola-Chieri.html']
# ['Trilocale via Modesto Moriondo 30, Rivalta di Torino', '€ 119.000', '3', '1', 'None', 'https://www.immobiliare.it/63852592-Vendita-Trilocale-via-Modesto-Moriondo-30-Rivalta-di-Torino.html']
# ['Trilocale via Morazzone, Torino', '€ 156.000', '3', '1', '75', 'https://www.immobiliare.it/63855156-Vendita-Trilocale-via-Morazzone-Torino.html']
# ['Appartamento via Spano 14-6, Torino', '€ 310.000', '5+', '2', '155', 'https://www.immobiliare.it/63857430-Vendita-Appartamento-via-Spano-14-6-Torino.html']
# ['Quadrilocale via Freinetto 51, Coazze', '€ 92.000', '4', '1', '100', 'https://www.immobiliare.it/63857386-Vendita-Quadrilocale-via-Freinetto-51-Coazze.html']
# ['Monolocale via Spano 14-6, Torino', '€ 98.000', '1', '1', '50', 'https://www.immobiliare.it/63857424-Vendita-Monolocale-via-Spano-14-6-Torino.html']
# ['Appartamento strada Comunale Santa Margherita, Torino', '€ 465.000', '5', '2', '168', 'https://www.immobiliare.it/63857464-Vendita-Appartamento-strada-Comunale-Santa-Torino.html']
# ['Trilocale via Riva 24, Moriondo Torinese', '€ 155.000', '3', '1', '105', 'https://www.immobiliare.it/63857360-Vendita-Trilocale-via-Riva-24-Moriondo-Torinese.html']
# ['Bilocale via Vittorio Emanuele II 47, Chieri', '€ 125.000', '2', '1', '74', 'https://www.immobiliare.it/63857366-Vendita-Bilocale-via-Vittorio-Emanuele-II-47-Chieri.html']
# ['Monolocale via Spano 14-6, Torino', '€ 98.000', '1', '1', '50', 'https://www.immobiliare.it/63857422-Vendita-Monolocale-via-Spano-14-6-Torino.html']
# ['Bilocale via Piedicavallo, Torino', '€ 58.000', '2', '1', '45', 'https://www.immobiliare.it/63860838-Vendita-Bilocale-via-Piedicavallo-Torino.html']
# ['Quadrilocale corso Roma, Moncalieri', '€ 149.000', '1', '90', 'None', 'https://www.immobiliare.it/63856608-Vendita-Quadrilocale-corso-Roma-Moncalieri.html']
# ['Appartamento via Spano 14-6, Torino', '€ 288.000', '5+', '2', '155', 'https://www.immobiliare.it/63857428-Vendita-Appartamento-via-Spano-14-6-Torino.html']
# ['Trilocale strada Comunale Superga 298, Torino', '€ 220.000', '3', '1', '90', 'https://www.immobiliare.it/63857472-Vendita-Trilocale-strada-Comunale-Superga-298-Torino.html']
# ['Trilocale via Arona 7, Torino', '€ 85.000', '3', '1', '66', 'https://www.immobiliare.it/63857500-Vendita-Trilocale-via-Arona-7-Torino.html']
# ['Quadrilocale via Spano 6-10, Torino', '€ 288.000', '4', '2', '122', 'https://www.immobiliare.it/63857426-Vendita-Quadrilocale-via-Spano-6-10-Torino.html']
# ['Quadrilocale strada del Portone 35-6, Torino', '€ 205.000', '4', '1', '95', 'https://www.immobiliare.it/63857448-Vendita-Quadrilocale-strada-del-Portone-35-6-Torino.html']
# ['Quadrilocale via Guglielmo Marconi 58, Carmagnola', '€ 149.000', '4', '1', 'None', 'https://www.immobiliare.it/63857058-Vendita-Quadrilocale-via-Guglielmo-Marconi-58-Carmagnola.html']
# ['Villa via colombo, Orbassano', '€ 379.000', '5+', '3', '300', 'https://www.immobiliare.it/63858264-Vendita-Villa-via-colombo-Orbassano.html']

# %%
# now we need to substitute the print() with something that push that data on the db 
# how we can push some data there

# fists we create a session, that open a connection with the db
s = session()
# that we need to associate the data with an instance of our table class and post there
post = MyTable( address = 'the address i want to post',
                price = '10000',
                rooms = '2',
                bathrooms = '1',
                area = '100',
                url = 'http://myfakeurl.com/blablabla'
             )   
# add the post to the session
s.add(post)
# commit our post
s.commit()

# %%
# now we are ready to put all rows there
file = open('data.csv','r')
reader = csv.reader(file)
counter = 0 
for row in reader:
    if counter > 0:
        s = session()
        post = MyTable( address = row[0],
                    price =  row[1],
                    rooms =  row[2],
                    bathrooms =  row[3],
                    area =  row[4],
                    url =  row[5]
                 ) 
        s.add(post)
        s.commit()
        counter += 1
    else:
        counter += 1
        pass

# %%
# ok, and now what we can see that data?
# introducing Pandas
import pandas as pd
import sqlite3

# pandas can connect to the db and visualize it's content
conn = sqlite3.connect("database.sqlite")
df = pd.read_sql_query("SELECT * FROM mytable;", conn)
df
# Out:
#     id                                            address      price rooms  \
# 0    1                         the address i want to post      10000     2
# 1    2          Trilocale via pinerolo, Rivalta di Torino   € 78.000     3
# 2    3  Bilocale via Luigi Salvatore Cherubini 20, Torino   € 49.000     2
# 3    4  Quadrilocale via Luigi Salvatore Cherubini 20,...   € 79.000     4
# 4    5                   Quadrilocale via Bibiana, Torino  € 108.000     2
# 5    6             Quadrilocale corso Monte Cucco, Torino  € 218.000     4
# 6    7             Bilocale via Erminio Macario 8, Chieri   € 90.000     2
# 7    8                  Appartamento via Amendola, Chieri  € 260.000     5
# 8    9  Trilocale via Modesto Moriondo 30, Rivalta di ...  € 119.000     3
# 9   10                    Trilocale via Morazzone, Torino   99999999     3
# 10  11                Appartamento via Spano 14-6, Torino  € 310.000    5+
# 11  12              Quadrilocale via Freinetto 51, Coazze   € 92.000     4
# 12  13                  Monolocale via Spano 14-6, Torino   € 98.000     1
# 13  14  Appartamento strada Comunale Santa Margherita,...  € 465.000     5
# 14  15           Trilocale via Riva 24, Moriondo Torinese  € 155.000     3
# 15  16       Bilocale via Vittorio Emanuele II 47, Chieri  € 125.000     2
# 16  17                  Monolocale via Spano 14-6, Torino   € 98.000     1
# 17  18                  Bilocale via Piedicavallo, Torino   € 58.000     2
# 18  19                Quadrilocale corso Roma, Moncalieri  € 149.000     1
# 19  20                Appartamento via Spano 14-6, Torino  € 288.000    5+
# 20  21      Trilocale strada Comunale Superga 298, Torino  € 220.000     3
# 21  22                      Trilocale via Arona 7, Torino   € 85.000     3
# 22  23                Quadrilocale via Spano 6-10, Torino  € 288.000     4
# 23  24       Quadrilocale strada del Portone 35-6, Torino  € 205.000     4
# 24  25  Quadrilocale via Guglielmo Marconi 58, Carmagnola  € 149.000     4
# 25  26                       Villa via colombo, Orbassano  € 379.000    5+
# 26  27                         the address i want to post      10000     2
# 27  28          Trilocale via pinerolo, Rivalta di Torino   € 78.000     3
# 7 Bilocale via Erminio Macario 8, Chieri € 90.000 2
# 8 Appartamento via Amendola, Chieri € 260.000 5
# 9 Trilocale via Modesto Moriondo 30, Rivalta di Torino € 119.000 3
# 10 Trilocale via Morazzone, Torino 99999999 3
# 11 Appartamento via Spano 14-6, Torino € 310.000 5+
# 12 Quadrilocale via Freinetto 51, Coazze € 92.000 4
# 13 Monolocale via Spano 14-6, Torino € 98.000 1
# 14 Appartamento strada Comunale Santa Margherita, Torino € 465.000 5
# 15 Trilocale via Riva 24, Moriondo Torinese € 155.000 3
# 16 Bilocale via Vittorio Emanuele II 47, Chieri € 125.000 2
# 17 Monolocale via Spano 14-6, Torino € 98.000 1
# 18 Bilocale via Piedicavallo, Torino € 58.000 2
# 19 Quadrilocale corso Roma, Moncalieri € 149.000 1
# 20 Appartamento via Spano 14-6, Torino € 288.000 5+
# 21 Trilocale strada Comunale Superga 298, Torino € 220.000 3
# 22 Trilocale via Arona 7, Torino € 85.000 3
# 23 Quadrilocale via Spano 6-10, Torino € 288.000 4
# 24 Quadrilocale strada del Portone 35-6, Torino € 205.000 4
# 25 Quadrilocale via Guglielmo Marconi 58, Carmagnola € 149.000 4
# 26 Villa via colombo, Orbassano € 379.000 5+
# 27 the address i want to post 10000 2
# 28 Trilocale via pinerolo, Rivalta di Torino € 78.000 3
# 29 Bilocale via Luigi Salvatore Cherubini 20, Torino € 49.000 2
# 30 Quadrilocale via Luigi Salvatore Cherubini 20, Torino € 79.000 4
# 31 Quadrilocale via Bibiana, Torino € 108.000 2
# 32 Quadrilocale corso Monte Cucco, Torino € 218.000 4
# 33 Bilocale via Erminio Macario 8, Chieri € 90.000 2
# 34 Appartamento via Amendola, Chieri € 260.000 5
# 35 Trilocale via Modesto Moriondo 30, Rivalta di Torino € 119.000 3
# 36 Trilocale via Morazzone, Torino € 156.000 3
# 37 Appartamento via Spano 14-6, Torino € 310.000 5+
# 38 Quadrilocale via Freinetto 51, Coazze € 92.000 4
# 39 Monolocale via Spano 14-6, Torino € 98.000 1
# 40 Appartamento strada Comunale Santa Margherita, Torino € 465.000 5
# 41 Trilocale via Riva 24, Moriondo Torinese € 155.000 3
# 42 Bilocale via Vittorio Emanuele II 47, Chieri € 125.000 2
# 43 Monolocale via Spano 14-6, Torino € 98.000 1
# 44 Bilocale via Piedicavallo, Torino € 58.000 2
# 45 Quadrilocale corso Roma, Moncalieri € 149.000 1
# 46 Appartamento via Spano 14-6, Torino € 288.000 5+
# 47 Trilocale strada Comunale Superga 298, Torino € 220.000 3
# 48 Trilocale via Arona 7, Torino € 85.000 3
# 49 Quadrilocale via Spano 6-10, Torino € 288.000 4
# 50 Quadrilocale strada del Portone 35-6, Torino € 205.000 4
# 51 Quadrilocale via Guglielmo Marconi 58, Carmagnola € 149.000 4
# 52 Villa via colombo, Orbassano € 379.000 5+
# results:  52

# %%
# pull out data from the db with filters 
s = session()
# shrink a little the work
results = s.query(MyTable).filter(MyTable.area != 'None')
for r in results:
    print(r.address,r.price,r.rooms)
print('results: ',results.count())
# Out:
# the address i want to post 10000 2
# Bilocale via Luigi Salvatore Cherubini 20, Torino € 49.000 2
# Quadrilocale via Luigi Salvatore Cherubini 20, Torino € 79.000 4
# Quadrilocale corso Monte Cucco, Torino € 218.000 4
# Bilocale via Erminio Macario 8, Chieri € 90.000 2
# Appartamento via Amendola, Chieri € 260.000 5
# Trilocale via Morazzone, Torino 99999999 3
# Appartamento via Spano 14-6, Torino € 310.000 5+
# Quadrilocale via Freinetto 51, Coazze € 92.000 4
# Monolocale via Spano 14-6, Torino € 98.000 1
# Appartamento strada Comunale Santa Margherita, Torino € 465.000 5
# Trilocale via Riva 24, Moriondo Torinese € 155.000 3
# Bilocale via Vittorio Emanuele II 47, Chieri € 125.000 2
# Monolocale via Spano 14-6, Torino € 98.000 1
# Bilocale via Piedicavallo, Torino € 58.000 2
# Appartamento via Spano 14-6, Torino € 288.000 5+
# Trilocale strada Comunale Superga 298, Torino € 220.000 3
# Trilocale via Arona 7, Torino € 85.000 3
# Quadrilocale via Spano 6-10, Torino € 288.000 4
# Quadrilocale strada del Portone 35-6, Torino € 205.000 4
# Villa via colombo, Orbassano € 379.000 5+
# the address i want to post 10000 2
# Bilocale via Luigi Salvatore Cherubini 20, Torino € 49.000 2
# Quadrilocale via Luigi Salvatore Cherubini 20, Torino € 79.000 4
# Quadrilocale corso Monte Cucco, Torino € 218.000 4
# Bilocale via Erminio Macario 8, Chieri € 90.000 2
# Appartamento via Amendola, Chieri € 260.000 5
# Trilocale via Morazzone, Torino € 156.000 3
# Appartamento via Spano 14-6, Torino € 310.000 5+
# Quadrilocale via Freinetto 51, Coazze € 92.000 4
# Monolocale via Spano 14-6, Torino € 98.000 1
# Appartamento strada Comunale Santa Margherita, Torino € 465.000 5
# Trilocale via Riva 24, Moriondo Torinese € 155.000 3
# Bilocale via Vittorio Emanuele II 47, Chieri € 125.000 2
# Monolocale via Spano 14-6, Torino € 98.000 1
# Bilocale via Piedicavallo, Torino € 58.000 2
# Appartamento via Spano 14-6, Torino € 288.000 5+
# Trilocale strada Comunale Superga 298, Torino € 220.000 3
# Trilocale via Arona 7, Torino € 85.000 3
# Quadrilocale via Spano 6-10, Torino € 288.000 4
# Quadrilocale strada del Portone 35-6, Torino € 205.000 4
# Villa via colombo, Orbassano € 379.000 5+
# results:  42

# %%
# update a specific rows with ids 
s = session()
s.query(MyTable).filter(MyTable.id == 10).update({'price': '99999999'})
s.commit()

# %%
s = session()
# shrink a little the work
results = s.query(MyTable).filter(MyTable.id == 10)
for r in results:
    print(r.address,r.price,r.rooms)
print('results: ',results.count())
# Out:
# Trilocale via Morazzone, Torino 99999999 3
# results:  1
